# %% [markdown]
# # Kaggle Housing Prices - EDA
#
# This notebook contains some data exploration for the Housing Prices Kaggle competition.
# The purpose of this file is to examine the relationship between features and the target in the training dataset.
#
# This was written before knowing about correlation matrices.

# %% [markdown]
# ## Visualize data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2  \
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
y = df['SalePrice']

# %%
plt.scatter(df['MSSubClass'], y)
plt.xlabel('MSSubClass')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. MSSubClass')

plt.show()

# %%
plt.scatter(df['MSZoning'], y)
plt.xlabel('MSZoning')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. MSZoning')

plt.show()

# %%
plt.scatter(df['LotFrontage'], y)
plt.xlabel('LotFrontage')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. LotFrontage')

plt.show()

# %%
plt.scatter(df['LotArea'], y)
plt.xlabel('LotArea')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. LotArea')

plt.show()

# %%
plt.scatter(df['Street'], y)
plt.xlabel('Street')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Street')

plt.show()

# %%
plt.scatter(df['LandContour'], y)
plt.xlabel('LandContour')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. LandContour')

plt.show()

# %%
plt.scatter(df['Utilities'], y)
plt.xlabel('Utilities')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Utilities')

plt.show()

# %%
plt.scatter(df['LotConfig'], y)
plt.xlabel('LotConfig')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. LotConfig')

plt.show()

# %%
plt.scatter(df['LandSlope'], y)
plt.xlabel('LandSlope')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. LandSlope')

plt.show()

# %%
plt.scatter(df['Neighborhood'], y)
plt.xlabel('Neighborhood')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Neighborhood')

plt.show()

# %%
plt.scatter(df['Condition1'], y)
plt.xlabel('Condition1')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Condition1')

plt.show()

# %%
plt.scatter(df['Condition2'], y)
plt.xlabel('Condition2')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Condition2')

plt.show()

# %%
plt.scatter(df['BldgType'], y)
plt.xlabel('BldgType')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. BldgType')

plt.show()

# %%
plt.scatter(df['HouseStyle'], y)
plt.xlabel('HouseStyle')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. HouseStyle')

plt.show()

# %%
plt.scatter(df['OverallQual'], y)
plt.xlabel('OverallQual')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. OverallQual')

plt.show()

# %%
plt.scatter(df['OverallCond'], y)
plt.xlabel('OverallCond')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. OverallCond')

plt.show()

# %%
plt.scatter(df['YearBuilt'], y)
plt.xlabel('YearBuilt')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. YearBuilt')

plt.show()

# %%
plt.scatter(df['YearRemodAdd'], y)
plt.xlabel('YearRemodAdd')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. YearRemodAdd')

plt.show()

# %%
plt.scatter(df['RoofStyle'], y)
plt.xlabel('RoofStyle')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. RoofStyle')

plt.show()

# %%
plt.scatter(df['RoofMatl'], y)
plt.xlabel('RoofMatl')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. RoofMatl')

plt.show()

# %%
plt.scatter(df['Exterior1st'], y)
plt.xlabel('Exterior1st')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Exterior1st')

plt.show()

# %%
plt.scatter(df['Exterior2nd'], y)
plt.xlabel('Exterior2nd')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Exterior2nd')

plt.show()

# %%
plt.scatter(df['MasVnrType'].astype('str'), y)
plt.xlabel('MasVnrType')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. MasVnrType')

plt.show()

# %%
plt.scatter(df['MasVnrArea'], y)
plt.xlabel('MasVnrArea')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. MasVnrArea')

plt.show()

# %%
plt.scatter(df['ExterQual'], y)
plt.xlabel('ExterQual')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. ExterQual')

plt.show()

# %%
plt.scatter(df['ExterCond'], y)
plt.xlabel('ExterCond')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. ExterCond')

plt.show()

# %%
plt.scatter(df['Foundation'], y)
plt.xlabel('Foundation')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. Foundation')

plt.show()

# %%
plt.scatter(df['BsmtQual'].astype('str'), y)
plt.xlabel('BsmtQual')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. BsmtQual')

plt.show()

# %%
plt.scatter(df['BsmtCond'].astype('str'), y)
plt.xlabel('BsmtCond')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. BsmtCond')

plt.show()

# %%
plt.scatter(df['BsmtExposure'].astype('str'), y)
plt.xlabel('BsmtExposure')
plt.ylabel('Sale Price')

plt.title('Sale Price vs. BsmtExposure')

plt.show()
